# %%
import matplotlib.pyplot as plt
x_axis = ['Lee','Duval','Orange','Hills.','Bro.','Mi.-Dade','Total']
y_axis = ['14,336','24,437','27,422','28,020','41,381','62,536','401,540']

plt.bar(x_axis, y_axis)
plt.title('Annual Car Crashes')
plt.xlabel('Counties')
plt.ylabel('Number of Crashes')
plt.show()

# %%
import matplotlib.pyplot as plt

# Data which shows the frequency of the deaths per county
#The frequencies are for the purposes of a range of data for the counties. So, each county is represented by a range, and counted as a value of a hundred. For instance, all the 100 values range from 0-100, as the frequency of car crashes.
data = [100,100,100,100,100,100,100,100,100,100,100,100,100,100,100,100,100,100,100,100100,100,100,100,100,100,100,100,100,100100,100,100,100,100,100,100,100,100,100100,100,100,100,100,100,100,100,100,100,100,100,100,100,100,200,200,200,200,200,200,300,300,300,400,400]


plt.hist(data, bins=10)


plt.title('Death Frequencies')
plt.xlabel('Values')
plt.ylabel('Frequency')

# Display the data
plt.show()
