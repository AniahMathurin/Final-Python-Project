# %%
import matplotlib as mat
mat.__version__
# Out:
# '3.3.4'

# %%
import pandas as pd
pd.__version__
# Out:
# '1.1.5'

# %%
import numpy as np
np.__version__
# Out:
# '1.19.5'

# %%
import seaborn as sns
sns.__version__
# Out:
# '0.11.2'

# %%
import csv

# %%
pd.read_csv("Car Crashes.csv")
# Out:
#    Motor Vehicle Traffic Crashes, Rate Per 100,000 Population Unnamed: 1  \
# 0                                                 NaN               2021
# 1                                              County              Count
# 2                                             Florida             401540
# 3                                             Alachua               5193
# 4                                               Baker                442
# ..                                                ...                ...
# 66                                            Volusia              10497
# 67                                            Wakulla                436
# 68                                             Walton               1692
# 69                                         Washington                388
# 70                                            Unknown                  2
#
#     Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5  Unnamed: 6 Unnamed: 7  \
# ...

# %%
import csv
df = pd.read_csv("Car Crashes.csv")
print(df)
# Out:
#    Motor Vehicle Traffic Crashes, Rate Per 100,000 Population Unnamed: 1  \
# 0                                                 NaN               2021
# 1                                              County              Count
# 2                                             Florida             401540
# 3                                             Alachua               5193
# 4                                               Baker                442
# ..                                                ...                ...
# 66                                            Volusia              10497
# 67                                            Wakulla                436
# 68                                             Walton               1692
# 69                                         Washington                388
# 70                                            Unknown                  2
#
#     Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5  Unnamed: 6 Unnamed: 7  \
# ...

# %%
import matplotlib.pyplot as plt

x_axis = ['Avg','Mi.-Dade','Mad.','Colombia','Duval','Bay','Hamilton']
y_axis = ['1,824','2,186.1','2,348.0','2,443.9','2,456.5','2,523','2,545']

plt.bar(x_axis, y_axis)
plt.title('Car Crashes per County (Rate)')
plt.xlabel('Counties')
plt.ylabel('Rate of Crashes')
plt.show()

# %%
pd.read_csv('Car Deaths.csv')
# Out:
#    Age-adjusted Deaths From Motor Vehicle Crashes, Rate Per 100,000 Population  \
# 0                                                 NaN
# 1                                              County
# 2                                             Florida
# 3                                             Alachua
# 4                                               Baker
# ..                                                ...
# 65                                              Union
# 66                                            Volusia
# 67                                            Wakulla
# 68                                             Walton
# 69                                         Washington
#
#    Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6  \
# 0        2021        NaN       2020        NaN       2019        NaN
# 1       Count       Rate      Count       Rate      Count       Rate
# 2       3,863       17.0      3,484       15.6      3,273       14.7
# ...

# %%
import matplotlib.pyplot as plt

x_axis = ['Avg','Lee','Duval','Orange','Hills.','Bro.','Mi.-Dade']
y_axis = ['401,540','14,336','24,437','27,422','28,020','41,381','62,536']

plt.bar(x_axis, y_axis)
plt.title('Annual Car Crashes')
plt.xlabel('Counties')
plt.ylabel('Rate of Crashes')
plt.show()

# %%
x_axis = ['Mi.-Dade','Avg.','Frank.','Oke.','Jackson','Calhoun','Hardee','Liberty']
y_axis = ['12.2','17.0','46.1','47,1','49.0','52.1','58.9','72.0']

plt.bar(x_axis, y_axis)
plt.title('Annual Car Death Rates')
plt.xlabel('Counties')
plt.ylabel('Rate of Deaths')
plt.show()

# %%
import matplotlib.pyplot as plt

x_axis = ['Duval','P. Beach','Orange','Hills.','Bro.','Mi.-Dade','Total']
y_axis = ['194','218','221','253','331','357','3,863']

plt.bar(x_axis, y_axis)
plt.title('Annual Deaths')
plt.xlabel('Counties')
plt.ylabel('Death Count')
plt.show()
